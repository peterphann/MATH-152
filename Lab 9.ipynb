# %% [markdown]
# ## MATH 152 Lab 9

# %% [markdown]
# Peter Phan, Luis Calvo Gerstner, Charles Williams (Section 530)

# %%
import sympy as sp
from sympy.plotting import (plot,plot_parametric)
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Question 1

# %% [markdown]
# #### 1a

# %%
n, x = sp.symbols('n x')
an = (-1)**n * (n + 1) * 9**(n + 1) * (x + 3)**(n + 2) / 5**(n + 3)
anp1 = an.subs(n, n+1)
ratio = sp.simplify(sp.Abs(anp1 / an))
L = sp.limit(ratio, n, sp.oo)
L
# Out:
# 9*Abs(x + 3)/5

# %% [markdown]
# #### 1b

# %% [markdown]
# #### 1c

# %%
f = 9 * (x + 3)**2 / (9 * x + 32)**2
s5 = sp.summation(an, (n, 0, 5))
s10 = sp.summation(an, (n, 0, 10))
s15 = sp.summation(an, (n, 0, 15))

p1 = plot(f, s5, s10, s15, (x, -4, -2), ylim=(-4, 4))

# %% [markdown]
# ### Question 2

# %% [markdown]
# #### 2a

# %%
n, x = sp.symbols('n x')
an = (-1)**n * x**(2 * n + 1) / (sp.factorial(n) * sp.factorial(n + 1) * 2**(2 * n + 1))
anp1 = an.subs(n, n+1)
ratio = sp.simplify(sp.Abs(anp1 / an))
L = sp.limit(ratio, n, sp.oo)
L
print('Since the limit as n approaches infinity is 0, the radius of convergence is (-inf, inf).')
# Out:
# Since the limit as n approaches infinity is 0, the radius of convergence is (-inf, inf).

# %% [markdown]
# #### 2b

# %%
J1 = sp.besselj(1, x)
an_list = [an.subs(n, i) for i in range(0, 10)]
sn = np.cumsum(an_list)
f1 = sn[0]
f2 = sn[1]
f3 = sn[2]
f4 = sn[3]
f5 = sn[4]

plot(f1, f2, f3, f4, f5, J1, (x, 0, 5), ylim=(-0.6, 0.6))

# %% [markdown]
# #### 2c

# %%
J1 = sp.besselj(1, x)
J2 = sp.besselj(2, x)
J3 = sp.besselj(3, x)
J4 = sp.besselj(4, x)
J5 = sp.besselj(5, x)

plot(J1, J2, J3, J4, J5, (x, 0, 5), ylim=(-0.6, 0.6))

# %% [markdown]
# ### Question 3

# %% [markdown]
# #### 3a

# %%
f = sp.sin(x)
a = 0

taylor_sum = 0
for i in range(11):
  taylor_sum += (x - a)**i * (sp.diff(f, x, i).subs({x:1}) / sp.factorial(i))

display(taylor_sum)
# Out:
# -x**10*sin(1)/3628800 + x**9*cos(1)/362880 + x**8*sin(1)/40320 - x**7*cos(1)/5040 - x**6*sin(1)/720 + x**5*cos(1)/120 + x**4*sin(1)/24 - x**3*cos(1)/6 - x**2*sin(1)/2 + x*cos(1) + sin(1)

# %% [markdown]
# #### 3b

# %% [markdown]
# #### 3c

# %% [markdown]
# #### 3d
