# %% [markdown]
# ## MATH 152 Lab  3

# %% [markdown]
# Peter Phan, Luis Calvo Gerstner, Charles Williams (Section 530)

# %%
import sympy as sp
from sympy.plotting import (plot,plot_parametric)

# %% [markdown]
# Instructions: Complete the lab assignment in your assigned groups. Unless stated otherwise, your answers should be obtained using Python code.
#
# Do not modify the cell above, as it contains all the packages you will need. It is highly recommended to not use any additional packages.
#
# NOTE: If you took MATH 151 last semester, notice that the import statement for SymPy is different- for each SymPy command you use, you have to preface it with "sp." For example, "symbols('x')" becomes "sp.symbols('x')". **Except for plot and plot_parametric**- you don't need to type "sp." for those.
#
# ANOTHER NOTE: Approximate answers are acceptable for all non-plotting parts of this week's lab.

# %% [markdown]
# ### Question 1

# %% [markdown]
# #### 1a

# %%
matplotlib notebook

# %%
# Enter your Python code here
x = sp.symbols('x')
f = sp.sqrt(x)
g = (x - 3)**2

# 1
fig = plot(f, g, (x, 0, 5))

# %% [markdown]
# #### 1b

# %%
# Enter your Python code here
r = x - 1
h = f - g
shell = 2 * sp.pi * r * h

bounds = sp.solve(f - g, x)

volume_shell = sp.integrate(shell, (x, bounds[1], bounds[0]))
volume_shell.evalf()
# Out:
# 41.1718167309258

# %% [markdown]
# #### 1c

# %%
# Enter your Python code here
r1 = 4 - g
r2 = 4 - f
washer = sp.pi * ((r1 ** 2) - (r2 ** 2))
volume_washer = sp.integrate(washer, (x, bounds[1], bounds[0]))
volume_washer.evalf()
# Out:
# 56.4095852227308

# %% [markdown]
# ### Question 2

# %% [markdown]
# #### 2a

# %%
# Enter your Python code here
x = sp.symbols('x')
f = 2 * sp.exp(x ** 2)
g = 3 * x + 2

fig3 = plot(f, (x, 0, 1), show = False)
fig4 = plot(g, (x, 0, 1), show = False)
fig3.extend(fig4)
fig3.show()

# %% [markdown]
# #### 2b

# %%
# Enter your Python code here
slice = sp.sqrt(3) / 4 * ((g - f) ** 2)
bounds = sp.nsolve(f - g, 1)

volume_slices = sp.integrate(slice, (x, 0, bounds))
volume_slices.evalf()
# Out:
# 0.191894750193957

# %% [markdown]
# ### Question 3

# %% [markdown]
# #### 3a

# %%
# Enter your Python code here
a = sp.pi * (400 - y**2)
d = 22 - y
layer = 900 * 9.8 * a * d
work = sp.integrate(layer, (y, -20, 20))
work.evalf()
# Out:
# 6502342810.69401

# %% [markdown]
# #### 3b

# %%
# Enter your Python code here
h = sp.symbols('h')
work = sp.integrate(layer, (y, -20 + h, 20))
display(sp.simplify(work))
# Out:
# pi*(-2205.0*h**4 + 241080.0*h**3 - 7408800.0*h**2 + 2069760000.0)
